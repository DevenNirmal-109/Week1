# %% [markdown]
# ## Solar power prediction using linear regeression

# %%
# import necessary library

import pandas as pd
import numpy as np
import seaborn as sns

# %%
#load data set 

df= pd.read_csv('D:\Internship\dataset\solarpowergeneration.csv')
 
# display the first few rows of the data set 

df.head()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\I'
# <>:3: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\deven\AppData\Local\Temp\ipykernel_18668\121569555.py:3: SyntaxWarning: invalid escape sequence '\I'
#   df= pd.read_csv('D:\Internship\dataset\solarpowergeneration.csv')
#    temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# 0                       2.17                               31
# 1                       2.31                               27
# 2                       3.65                               33
# 3                       5.82                               30
# 4                       7.73                               27
#
#    mean_sea_level_pressure_MSL  total_precipitation_sfc  snowfall_amount_sfc  \
# 0                       1035.0                      0.0                  0.0
# 1                       1035.1                      0.0                  0.0
# 2                       1035.4                      0.0                  0.0
# ...

# %%
df.tail()
# Out:
#       temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# 4208                       8.69                               66
# 4209                       7.57                               90
# 4210                       7.27                               90
# 4211                       8.25                               81
# 4212                       8.00                               80
#
#       mean_sea_level_pressure_MSL  total_precipitation_sfc  \
# 4208                       1025.1                      0.0
# 4209                       1026.1                      0.0
# 4210                       1026.3                      0.1
# 4211                       1025.5                      0.0
# 4212                       1025.3                      0.0
#
#       snowfall_amount_sfc  total_cloud_cover_sfc  \
# 4208                  0.0                  100.0
# 4209                  0.0                  100.0
# 4210                  0.0                  100.0
# ...

# %%
df.head(10)
# Out:
#    temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# 0                       2.17                               31
# 1                       2.31                               27
# 2                       3.65                               33
# 3                       5.82                               30
# 4                       7.73                               27
# 5                       8.69                               29
# 6                       9.72                               27
# 7                      10.07                               28
# 8                       9.38                               32
# 9                       6.54                               47
#
#    mean_sea_level_pressure_MSL  total_precipitation_sfc  snowfall_amount_sfc  \
# 0                       1035.0                      0.0                  0.0
# 1                       1035.1                      0.0                  0.0
# ...

# %%
# to check how many rows and cols are present 

df.shape
# Out:
# (4213, 21)

# %%
#Display summery 
df.describe()
# Out:
#        temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# count                4213.000000                      4213.000000
# mean                   15.068111                        51.361025
# std                     8.853677                        23.525864
# min                    -5.350000                         7.000000
# 25%                     8.390000                        32.000000
# 50%                    14.750000                        48.000000
# 75%                    21.290000                        70.000000
# max                    34.900000                       100.000000
#
#        mean_sea_level_pressure_MSL  total_precipitation_sfc  \
# count                  4213.000000              4213.000000
# mean                   1019.337812                 0.031759
# std                       7.022867                 0.170212
# min                     997.500000                 0.000000
# 25%                    1014.500000                 0.000000
# ...

# %%
#Check the information of th datasetm

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4213 entries, 0 to 4212
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   temperature_2_m_above_gnd          4213 non-null   float64
#  1   relative_humidity_2_m_above_gnd    4213 non-null   int64
#  2   mean_sea_level_pressure_MSL        4213 non-null   float64
#  3   total_precipitation_sfc            4213 non-null   float64
#  4   snowfall_amount_sfc                4213 non-null   float64
#  5   total_cloud_cover_sfc              4213 non-null   float64
#  6   high_cloud_cover_high_cld_lay      4213 non-null   int64
#  7   medium_cloud_cover_mid_cld_lay     4213 non-null   int64
#  8   low_cloud_cover_low_cld_lay        4213 non-null   int64
#  9   shortwave_radiation_backwards_sfc  4213 non-null   float64
#  10  wind_speed_10_m_above_gnd          4213 non-null   float64
# ...

# %%
#Check for missing value 

df.isnull().sum()
df.notnull().sum()
# Out:
# temperature_2_m_above_gnd            4213
# relative_humidity_2_m_above_gnd      4213
# mean_sea_level_pressure_MSL          4213
# total_precipitation_sfc              4213
# snowfall_amount_sfc                  4213
# total_cloud_cover_sfc                4213
# high_cloud_cover_high_cld_lay        4213
# medium_cloud_cover_mid_cld_lay       4213
# low_cloud_cover_low_cld_lay          4213
# shortwave_radiation_backwards_sfc    4213
# wind_speed_10_m_above_gnd            4213
# wind_direction_10_m_above_gnd        4213
# wind_speed_80_m_above_gnd            4213
# wind_direction_80_m_above_gnd        4213
# wind_speed_900_mb                    4213
# wind_direction_900_mb                4213
# wind_gust_10_m_above_gnd             4213
# angle_of_incidence                   4213
# zenith                               4213
# azimuth                              4213
# generated_power_kw                   4213
# dtype: int64

# %%
#Check duplicate values 

df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['temperature_2_m_above_gnd', 'relative_humidity_2_m_above_gnd',
#        'mean_sea_level_pressure_MSL', 'total_precipitation_sfc',
#        'snowfall_amount_sfc', 'total_cloud_cover_sfc',
#        'high_cloud_cover_high_cld_lay', 'medium_cloud_cover_mid_cld_lay',
#        'low_cloud_cover_low_cld_lay', 'shortwave_radiation_backwards_sfc',
#        'wind_speed_10_m_above_gnd', 'wind_direction_10_m_above_gnd',
#        'wind_speed_80_m_above_gnd', 'wind_direction_80_m_above_gnd',
#        'wind_speed_900_mb', 'wind_direction_900_mb',
#        'wind_gust_10_m_above_gnd', 'angle_of_incidence', 'zenith', 'azimuth',
#        'generated_power_kw'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
# Plot distribution of power
plt.figure(figsize=(10, 6))
sns.histplot(x='generated_power_kw', data=df, bins=30, kde=True)
plt.title("Power generated in KW")
plt.xlabel("Generated power ")
plt.ylabel("Frequency")
plt.show()
